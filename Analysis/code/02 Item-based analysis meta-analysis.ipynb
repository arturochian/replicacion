# %% [markdown]
# # Loading packages

# %%
import numpy as np
import pandas as pd
import glob

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from pandas.api.types import CategoricalDtype

# %% [markdown]
# # Loading data

# %%
data= pd.read_pickle("../data/modified_exclusions/pt_replication_modified_exclusions_data.pkl")

# %% [markdown]
# # Create original PT proportions

# %%
original_pt_proportions = pd.Series([0.18, 0.83, 0.20, 0.65, 0.14, 0.73, 0.92, 0.42, 0.92, 0.30, 0.22, 0.16, 0.69, 0.18, 0.70, 0.72, 0.17],
                                   index=[str(i) for i in np.arange(1, 18)])
original_pt_proportions
# Out:
# 1     0.18
# 2     0.83
# 3     0.20
# 4     0.65
# 5     0.14
# 6     0.73
# 7     0.92
# 8     0.42
# 9     0.92
# 10    0.30
# 11    0.22
# 12    0.16
# 13    0.69
# 14    0.18
# 15    0.70
# 16    0.72
# 17    0.17
# dtype: float64

# %% [markdown]
# # Preparing long format data

# %%
long_data = data.groupby("Country")[[str(i) for i in np.arange(1, 18)]].mean().reset_index().melt(id_vars="Country", value_vars=[str(i) for i in np.arange(1, 18)],
                                                                                     var_name="Item", value_name="Proportion")

# %%
long_data2 = pd.DataFrame(original_pt_proportions)
long_data2 = long_data2.reset_index()
long_data2.columns = ["Item", "Proportion"]
long_data2["Item"] = long_data2["Item"].astype(str)
long_data2["Country"] = "Original"

# %% [markdown]
# # Data wrangling with the proportions

# %%
country_a_counts = data.groupby("Country")[[str(i) for i in np.arange(1, 18)]].sum()

# %%
country_sample_sizes = data.groupby("Country")[[str(i) for i in np.arange(1, 18)]].count()
country_b_counts = country_sample_sizes - country_a_counts

# %%
# %load_ext RWinOut

# %%
# %R -i country_a_counts
# %R -i country_sample_sizes
# %R -i country_b_counts
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:191: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   res = PandasDataFrame.from_items(items)

# %%
# %%R
# library(metafor)

# %%
# %%R
# rownames(country_a_counts)
# Out:
#  [1] "Australia"      "Austria"        "Belgium"        "Bulgaria"
#  [5] "Chile"          "Denmark"        "Germany"        "Hong Kong"
#  [9] "Hungary"        "Ireland"        "Italy"          "Mainland China"
# [13] "Norway"         "Serbia"         "Slovenia"       "Spain"
# [17] "Sweden"         "UK"             "USA"

# %%
# %%R
# fit = escalc(measure="PR", xi=country_a_counts$X1, ni=country_sample_sizes$X1, slab=rownames(country_a_counts))
# summary(fit)
# Out:
#        yi     vi    sei      zi  ci.lb  ci.ub
# 1  0.4468 0.0009 0.0296 15.0920 0.3888 0.5048
# 2  0.1982 0.0014 0.0378  5.2381 0.1240 0.2724
# 3  0.1927 0.0008 0.0285  6.7700 0.1369 0.2485
# 4  0.1811 0.0012 0.0342  5.2997 0.1141 0.2481
# 5  0.1862 0.0010 0.0323  5.7600 0.1228 0.2496
# 6  0.2000 0.0011 0.0327  6.1237 0.1360 0.2640
# 7  0.3333 0.0007 0.0261 12.7867 0.2822 0.3844
# 8  0.2250 0.0011 0.0330  6.8155 0.1603 0.2897
# 9  0.2551 0.0008 0.0280  9.1235 0.2003 0.3100
# 10 0.1406 0.0005 0.0217  6.4723 0.0980 0.1832
# 11 0.2658 0.0006 0.0255 10.4384 0.2159 0.3157
# 12 0.1892 0.0006 0.0243  7.7739 0.1415 0.2369
# 13 0.1770 0.0006 0.0254  6.9715 0.1272 0.2268
# 14 0.3211 0.0009 0.0298 10.7876 0.2628 0.3795
# 15 0.2475 0.0009 0.0304  8.1515 0.1880 0.3070
# 16 0.2764 0.0010 0.0317  8.7182 0.2142 0.3385
# 17 0.2230 0.0012 0.0353  6.3165 0.1538 0.2922
# 18 0.3138 0.0007 0.0272 11.5158 0.2604 0.3672
# 19 0.2510 0.0008 0.0278  9.0247 0.1965 0.3055

# %% [markdown]
# ### Running a random-effects log-odds model on the item-by-item response proportion. I chose log-odds because they tend to be normally distributed (which improves the validity of the model inferences) and because 0 means that people were indifferent between the options, which is the main effect we want to investigate.

# %%
# %%R
# model_list = list()
# estimate_list = list()
# lb_list = list()
# ub_list = list()
# z_list = list()
# p_list = list()
# I2_list = list()
# q_list = list()
# qp_list = list()
# X = 0
# for (item in c("X1", "X2", "X3", "X4", "X5", "X6", "X7", "X8", "X9", "X10",
#               "X11", "X12", "X13", "X14", "X15", "X16", "X17"))
# {
# X = X + 1
# fit = rma.uni(measure="PLO", xi=country_a_counts[[item]], ni=country_sample_sizes[[item]],
#               method="ML", slab=rownames(country_a_counts))
# print(item)
# print(summary(fit))
# model_list[[X]] = fit
# estimate_list[[X]] = fit$beta[[1]]
# lb_list[[X]] = fit$ci.lb
# ub_list[[X]] = fit$ci.ub
# z_list[[X]] = fit$zval
# p_list[[X]] = fit$pval
# I2_list[[X]] = fit$I2
# q_list[[X]] = fit$QM[[1]]
# qp_list[[X]] = fit$QMp
#
# }
# Out:
# [1] "X1"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -8.3505   50.0557   20.7009   22.5898   21.4509
#
# tau^2 (estimated amount of total heterogeneity): 0.1174 (SE = 0.0473)
# tau (square root of estimated tau^2 value):      0.3426
# I^2 (total heterogeneity / total variability):   82.19%
# H^2 (total variability / sampling variability):  5.61
#
# Test for Heterogeneity:
# Q(df = 18) = 119.1686, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.1452  0.0878  -13.0478  <.0001  -1.3173  -0.9732  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X2"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -1.5318   41.7131    7.0636    8.9525    7.8136
#
# tau^2 (estimated amount of total heterogeneity): 0.0476 (SE = 0.0222)
# tau (square root of estimated tau^2 value):      0.2182
# I^2 (total heterogeneity / total variability):   70.38%
# H^2 (total variability / sampling variability):  3.38
#
# Test for Heterogeneity:
# Q(df = 18) = 64.6697, p-val < .0001
#
# Model Results:
#
# estimate      se    zval    pval   ci.lb   ci.ub
#   0.4676  0.0602  7.7719  <.0001  0.3497  0.5855  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X3"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -8.7795   40.7790   21.5590   23.4479   22.3090
#
# tau^2 (estimated amount of total heterogeneity): 0.1028 (SE = 0.0486)
# tau (square root of estimated tau^2 value):      0.3206
# I^2 (total heterogeneity / total variability):   70.67%
# H^2 (total variability / sampling variability):  3.41
#
# Test for Heterogeneity:
# Q(df = 18) = 68.2713, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.9558  0.0893  -21.9040  <.0001  -2.1308  -1.7808  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X4"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -2.3388   44.2929    8.6776   10.5665    9.4276
#
# tau^2 (estimated amount of total heterogeneity): 0.0544 (SE = 0.0241)
# tau (square root of estimated tau^2 value):      0.2333
# I^2 (total heterogeneity / total variability):   74.14%
# H^2 (total variability / sampling variability):  3.87
#
# Test for Heterogeneity:
# Q(df = 18) = 72.7799, p-val < .0001
#
# Model Results:
#
# estimate      se    zval    pval    ci.lb   ci.ub
#   0.0388  0.0627  0.6187  0.5361  -0.0841  0.1616
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X5"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
# -15.4681   50.4112   34.9362   36.8251   35.6862
#
# tau^2 (estimated amount of total heterogeneity): 0.2177 (SE = 0.0898)
# tau (square root of estimated tau^2 value):      0.4666
# I^2 (total heterogeneity / total variability):   81.24%
# H^2 (total variability / sampling variability):  5.33
#
# Test for Heterogeneity:
# Q(df = 18) = 120.1234, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -2.1656  0.1213  -17.8540  <.0001  -2.4033  -1.9278  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X6"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#   5.3594   27.2699   -6.7188   -4.8299   -5.9688
#
# tau^2 (estimated amount of total heterogeneity): 0.0119 (SE = 0.0106)
# tau (square root of estimated tau^2 value):      0.1090
# I^2 (total heterogeneity / total variability):   36.41%
# H^2 (total variability / sampling variability):  1.57
#
# Test for Heterogeneity:
# Q(df = 18) = 29.5445, p-val = 0.0421
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   0.6338  0.0418  15.1698  <.0001  0.5519  0.7157  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X7"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -1.9214   35.0768    7.8427    9.7316    8.5927
#
# tau^2 (estimated amount of total heterogeneity): 0.0429 (SE = 0.0237)
# tau (square root of estimated tau^2 value):      0.2070
# I^2 (total heterogeneity / total variability):   59.76%
# H^2 (total variability / sampling variability):  2.49
#
# Test for Heterogeneity:
# Q(df = 18) = 48.2761, p-val = 0.0001
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   1.3635  0.0624  21.8583  <.0001  1.2412  1.4857  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X8"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#   1.4251   36.8828    1.1497    3.0386    1.8997
#
# tau^2 (estimated amount of total heterogeneity): 0.0304 (SE = 0.0162)
# tau (square root of estimated tau^2 value):      0.1742
# I^2 (total heterogeneity / total variability):   61.68%
# H^2 (total variability / sampling variability):  2.61
#
# Test for Heterogeneity:
# Q(df = 18) = 49.8609, p-val < .0001
#
# Model Results:
#
# estimate      se    zval    pval    ci.lb   ci.ub
#   0.0127  0.0514  0.2472  0.8048  -0.0880  0.1135
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X9"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -2.6714   36.7400    9.3428   11.2316   10.0928
#
# tau^2 (estimated amount of total heterogeneity): 0.0490 (SE = 0.0257)
# tau (square root of estimated tau^2 value):      0.2213
# I^2 (total heterogeneity / total variability):   62.84%
# H^2 (total variability / sampling variability):  2.69
#
# Test for Heterogeneity:
# Q(df = 18) = 52.3182, p-val < .0001
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   1.3581  0.0648  20.9504  <.0001  1.2311  1.4852  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X10"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -1.5135   42.2858    7.0269    8.9158    7.7769
#
# tau^2 (estimated amount of total heterogeneity): 0.0457 (SE = 0.0214)
# tau (square root of estimated tau^2 value):      0.2139
# I^2 (total heterogeneity / total variability):   70.30%
# H^2 (total variability / sampling variability):  3.37
#
# Test for Heterogeneity:
# Q(df = 18) = 61.7888, p-val < .0001
#
# Model Results:
#
# estimate      se     zval    pval    ci.lb    ci.ub
#  -0.2846  0.0591  -4.8186  <.0001  -0.4003  -0.1688  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X11"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -7.8580   42.9084   19.7160   21.6049   20.4660
#
# tau^2 (estimated amount of total heterogeneity): 0.0949 (SE = 0.0432)
# tau (square root of estimated tau^2 value):      0.3080
# I^2 (total heterogeneity / total variability):   72.85%
# H^2 (total variability / sampling variability):  3.68
#
# Test for Heterogeneity:
# Q(df = 18) = 75.7354, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.6763  0.0840  -19.9474  <.0001  -1.8411  -1.5116  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X12"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -4.9311   43.8160   13.8621   15.7510   14.6121
#
# tau^2 (estimated amount of total heterogeneity): 0.0699 (SE = 0.0314)
# tau (square root of estimated tau^2 value):      0.2644
# I^2 (total heterogeneity / total variability):   73.59%
# H^2 (total variability / sampling variability):  3.79
#
# Test for Heterogeneity:
# Q(df = 18) = 70.6696, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.1010  0.0716  -15.3795  <.0001  -1.2413  -0.9607  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X13"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -3.3322   45.1819   10.6644   12.5532   11.4144
#
# tau^2 (estimated amount of total heterogeneity): 0.0606 (SE = 0.0265)
# tau (square root of estimated tau^2 value):      0.2462
# I^2 (total heterogeneity / total variability):   75.19%
# H^2 (total variability / sampling variability):  4.03
#
# Test for Heterogeneity:
# Q(df = 18) = 74.5182, p-val < .0001
#
# Model Results:
#
# estimate      se    zval    pval   ci.lb   ci.ub
#   0.4716  0.0657  7.1737  <.0001  0.3428  0.6004  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X14"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -5.9372   39.9766   15.8744   17.7633   16.6244
#
# tau^2 (estimated amount of total heterogeneity): 0.0752 (SE = 0.0362)
# tau (square root of estimated tau^2 value):      0.2742
# I^2 (total heterogeneity / total variability):   68.65%
# H^2 (total variability / sampling variability):  3.19
#
# Test for Heterogeneity:
# Q(df = 18) = 64.4763, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.5399  0.0768  -20.0381  <.0001  -1.6905  -1.3893  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X15"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#   2.6615   33.1992   -1.3231    0.5658   -0.5731
#
# tau^2 (estimated amount of total heterogeneity): 0.0229 (SE = 0.0141)
# tau (square root of estimated tau^2 value):      0.1513
# I^2 (total heterogeneity / total variability):   53.21%
# H^2 (total variability / sampling variability):  2.14
#
# Test for Heterogeneity:
# Q(df = 18) = 40.2791, p-val = 0.0019
#
# Model Results:
#
# estimate      se    zval    pval   ci.lb   ci.ub
#   0.4699  0.0480  9.7809  <.0001  0.3758  0.5641  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X16"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -7.1922   53.3371   18.3843   20.2732   19.1343
#
# tau^2 (estimated amount of total heterogeneity): 0.1041 (SE = 0.0406)
# tau (square root of estimated tau^2 value):      0.3227
# I^2 (total heterogeneity / total variability):   84.13%
# H^2 (total variability / sampling variability):  6.30
#
# Test for Heterogeneity:
# Q(df = 18) = 118.9116, p-val < .0001
#
# Model Results:
#
# estimate      se    zval    pval   ci.lb   ci.ub
#   0.3065  0.0812  3.7742  0.0002  0.1473  0.4656  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "X17"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
#
#   logLik  deviance       AIC       BIC      AICc
#  -3.0582   45.3341   10.1163   12.0052   10.8663
#
# tau^2 (estimated amount of total heterogeneity): 0.0551 (SE = 0.0245)
# tau (square root of estimated tau^2 value):      0.2348
# I^2 (total heterogeneity / total variability):   74.01%
# H^2 (total variability / sampling variability):  3.85
#
# Test for Heterogeneity:
# Q(df = 18) = 67.7298, p-val < .0001
#
# Model Results:
#
# estimate      se     zval    pval    ci.lb    ci.ub
#  -0.2788  0.0632  -4.4152  <.0001  -0.4026  -0.1551  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %%
# %%R
# library(gtools)

# %% [markdown]
# ### Preparing tables for assessing heterogeneity and overall difference from chance

# %%
# %%R
# z_list = as.numeric(unlist(z_list))
# p_list = as.numeric(unlist(p_list))
# I2_list = as.numeric(unlist(I2_list))
# q_list = as.numeric(unlist(q_list))
# qp_list = as.numeric(unlist(qp_list))

# %%
# %R -o z_list
# %R -o p_list
# %R -o I2_list
# %R -o q_list
# %R -o qp_list
z_list = np.array(z_list)
p_list = np.array(p_list)
I2_list = np.array(I2_list)
q_list = np.array(q_list)
qp_list = np.array(qp_list)

# %%
q_list
# Out:
# array([1.70245661e+02, 6.04026862e+01, 4.79787135e+02, 3.82839332e-01,
#        3.18764681e+02, 2.30122812e+02, 4.77784798e+02, 6.11066118e-02,
#        4.38918864e+02, 2.32187725e+01, 3.97899686e+02, 2.36527559e+02,
#        5.14616843e+01, 4.01523456e+02, 9.56669503e+01, 1.42445640e+01,
#        1.94938233e+01])

# %%
het_df = pd.DataFrame([[str(x) for x in np.arange(1, 18)], q_list, qp_list, I2_list, z_list, p_list]).transpose()
het_df.columns = ["Item", "Q (df = 18)", "Q p-value", "I2", "z-statistic", "z p-value"]
het_df["Q (df = 18)"] = het_df["Q (df = 18)"].astype(float).round(2)
het_df["I2"] = het_df["I2"].astype(float).round(0).astype(int)
het_df["z-statistic"] = het_df["z-statistic"].astype(float).round(2)

het_df.to_excel("../output/Meta analysis proportions heterogeneity.xlsx", index=False)
het_df.to_csv("../output/Meta analysis proportions heterogeneity.csv", index=False)

# %% [markdown]
# ## Transforming estimates and upper and lower confidence bounds back to proportions

# %%
# %%R
# lb_list = sapply(as.numeric(unlist(lb_list)), inv.logit)
# ub_list = sapply(as.numeric(unlist(ub_list)), inv.logit)
# estimate_list = sapply(as.numeric(unlist(estimate_list)), inv.logit)
# p_list = as.numeric(unlist(p_list))

# %%
# %R -o lb_list
# %R -o ub_list
# %R -o estimate_list
# %R -o p_list
lb_list = np.array(lb_list)
ub_list = np.array(ub_list)
estimate_list = np.array(estimate_list)
p_list = np.array(p_list)

# %%
prop_df = pd.DataFrame([estimate_list, lb_list, ub_list, p_list]).transpose()
prop_df.columns = ["prop", "lb", "ub", "p-value"]
prop_df.head()
# Out:
#        prop        lb        ub        p-value
# 0  0.241358  0.211271  0.274240   6.539007e-39
# 1  0.614820  0.586543  0.642342   7.730740e-15
# 2  0.123918  0.106135  0.144201  2.377183e-106
# 3  0.509695  0.478994  0.540324   5.360876e-01
# 4  0.102886  0.082922  0.126991   2.691424e-71

# %%
prop_df["Item"] = [str(x) for x in np.arange(1, 18)]

# %%
prop_df["Succesful Replication"] = "Yes"
prop_df.loc[prop_df["p-value"]>.05, "Succesful Replication"] = "No"
prop_df.loc[prop_df["Item"]=="8", "Succesful Replication"] = "NA"

# %%
prop_df
# Out:
#         prop        lb        ub        p-value Item Succesful Replication
# 0   0.241358  0.211271  0.274240   6.539007e-39    1                   Yes
# 1   0.614820  0.586543  0.642342   7.730740e-15    2                   Yes
# 2   0.123918  0.106135  0.144201  2.377183e-106    3                   Yes
# 3   0.509695  0.478994  0.540324   5.360876e-01    4                    No
# 4   0.102886  0.082922  0.126991   2.691424e-71    5                   Yes
# 5   0.653349  0.634578  0.671655   5.604791e-52    6                   Yes
# 6   0.796322  0.775774  0.815435  6.482894e-106    7                   Yes
# 7   0.503177  0.478004  0.528333   8.047554e-01    8                    NA
# 8   0.795458  0.774008  0.815357   1.860989e-97    9                   Yes
# 9   0.429331  0.401232  0.457893   1.445791e-06   10                   Yes
# 10  0.157580  0.136926  0.180696   1.578155e-88   11                   Yes
# 11  0.249548  0.224203  0.276736   2.248409e-53   12                   Yes
# 12  0.615762  0.584859  0.645759   7.300817e-13   13                   Yes
# 13  0.176554  0.155712  0.199527   2.566250e-89   14                   Yes
# 14  0.615367  0.592850  0.637399   1.359309e-22   15                   Yes
# 15  0.576024  0.536763  0.614348   1.605238e-04   16                   Yes
# 16  0.430739  0.400685  0.461313   1.009255e-05   17                   Yes

# %%
prop_df.to_excel("../output/Meta analysis proportions.xlsx", index=False)
prop_df.to_csv("../output/Meta analysis proportions.csv", index=False)
