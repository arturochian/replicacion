# %% [markdown]
# # Loading packages

# %%
import numpy as np
import pandas as pd
import glob

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from pandas.api.types import CategoricalDtype

# %%
# %load_ext RWinOut

# %%
# %%R
# library(gtools)
# library(metafor)

# %% [markdown]
# # Loading data

# %% [markdown]
# ### Odds ratio country by country

# %%
PT_contrasts_df2 = pd.read_excel("../output/contrasts_by_country.xlsx")

# %%
PT_contrasts_df2.head()
# Out:
#     Country             Effect  Item 1  Item 2   A1   B1   A2  B2        OR  \
# 0  Bulgaria   Certainty Effect       1       2   23  104   72  55  0.168937
# 1  Bulgaria   Certainty Effect       3       4   15  112   65  62  0.127747
# 2  Bulgaria   Certainty Effect       7       8  109   18   76  51  4.063596
# 3  Bulgaria  Reflection Effect       3       7   15  112  109  18  0.022117
# 4  Bulgaria  Reflection Effect       4       8   65   62   76  51  0.703523
#
#         p-value        OR2  Significance Contrast  Sample Size Significant  \
# 0  2.425416e-10   5.919368          True   1 vs 2          127         Yes
# 1  1.080756e-11   7.827957          True   3 vs 4          127         Yes
# 2  4.697618e-06   4.063596          True   7 vs 8          127         Yes
# 3  5.761813e-35  45.214815          True   3 vs 7          127         Yes
# 4  2.066420e-01   1.421418         False   4 vs 8          127          No
#
#       LogOR  Significance2  LogOR_difference Replicates
# 0 -1.778230              1         -1.343796        Yes
# 1 -2.057702              1          0.040780        Yes
# 2  1.402068              1         -1.302852        Yes
# 3 -3.811425              1          0.038664        Yes
# 4 -0.351655              0         -1.300735         No

# %% [markdown]
# # Run meta-analytic models

# %%
# %R -i PT_contrasts_df2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\rpy2\robjects\pandas2ri.py:191: FutureWarning: from_items is deprecated. Please use DataFrame.from_dict(dict(items), ...) instead. DataFrame.from_dict(OrderedDict(items)) may be used to preserve the key order.
#   res = PandasDataFrame.from_items(items)

# %%
# %%R
# model_list = list()
# estimate_list = list()
# lb_list = list()
# ub_list = list()
# z_list = list()
# p_list = list()
# I2_list = list()
# q_list = list()
# qp_list = list()
# X = 0
# for (contrast in unique(PT_contrasts_df2$Contrast))
# {
# X = X + 1
# ai = PT_contrasts_df2[PT_contrasts_df2["Contrast"]==contrast, "A1"]
# bi = PT_contrasts_df2[PT_contrasts_df2["Contrast"]==contrast, "A2"]
# ci = PT_contrasts_df2[PT_contrasts_df2["Contrast"]==contrast, "B1"]
# di = PT_contrasts_df2[PT_contrasts_df2["Contrast"]==contrast, "B2"]
# fit = rma.glmm(ai, bi, ci, di, measure="OR", method="ML", model="UM.RS")
# print(contrast)
# print(summary(fit))
# model_list[[X]] = fit
# estimate_list[[X]] = fit$beta[[1]]
# lb_list[[X]] = fit$ci.lb
# ub_list[[X]] = fit$ci.ub
# z_list[[X]] = fit$zval
# p_list[[X]] = fit$pval
# I2_list[[X]] = fit$I2
# q_list[[X]] = fit$QE.LRT[[1]]
# qp_list[[X]] = fit$QEp.LRT
#
# }
# Out:
# [1] "1 vs 2"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -132.6400    36.0190   273.2800   279.8304   274.4922
#
# tau^2 (estimated amount of total heterogeneity): 0.0469
# tau (square root of estimated tau^2 value):      0.2166
# I^2 (total heterogeneity / total variability):   50.4988%
# H^2 (total variability / sampling variability):  2.0202
#
# sigma^2 (estimated amount of study level variability): 0.0020
# sigma (square root of estimated sigma^2 value):        0.0444
#
# Tests for Heterogeneity:
# Wld(df = 18) = 42.9385, p-val = 0.0008
# LRT(df = 18) = 43.4788, p-val = 0.0007
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.5810  0.0712  -22.2179  <.0001  -1.7205  -1.4415  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "3 vs 4"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -119.8679    21.3839   247.7358   254.2862   248.9480
#
# tau^2 (estimated amount of total heterogeneity): 0
# tau (square root of estimated tau^2 value):      0
# I^2 (total heterogeneity / total variability):   0.0000%
# H^2 (total variability / sampling variability):  1.0000
#
# sigma^2 (estimated amount of study level variability): 0.0028
# sigma (square root of estimated sigma^2 value):        0.0534
#
# Tests for Heterogeneity:
# Wld(df = 18) = 21.3694, p-val = 0.2612
# LRT(df = 18) = 21.3839, p-val = 0.2605
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.9699  0.0571  -34.5001  <.0001  -2.0818  -1.8580  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "7 vs 8"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -119.7544     9.8638   247.5088   254.0591   248.7209
#
# tau^2 (estimated amount of total heterogeneity): 0
# tau (square root of estimated tau^2 value):      0
# I^2 (total heterogeneity / total variability):   0.0000%
# H^2 (total variability / sampling variability):  1.0000
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 9.8192, p-val = 0.9376
# LRT(df = 18) = 9.8638, p-val = 0.9363
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   1.3328  0.0497  26.8418  <.0001  1.2355  1.4302  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "3 vs 7"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -129.1270    29.7993   266.2540   272.8043   267.4661
#
# tau^2 (estimated amount of total heterogeneity): 0.1873
# tau (square root of estimated tau^2 value):      0.4327
# I^2 (total heterogeneity / total variability):   72.0132%
# H^2 (total variability / sampling variability):  3.5731
#
# sigma^2 (estimated amount of study level variability): 0.0033
# sigma (square root of estimated sigma^2 value):        0.0577
#
# Tests for Heterogeneity:
# Wld(df = 18) = 43.1627, p-val = 0.0008
# LRT(df = 18) = 56.5897, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -3.3324  0.1188  -28.0540  <.0001  -3.5652  -3.0996  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "4 vs 8"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -131.6142     5.4950   271.2283   277.7787   272.4404
#
# tau^2 (estimated amount of total heterogeneity): 0.1030
# tau (square root of estimated tau^2 value):      0.3209
# I^2 (total heterogeneity / total variability):   73.1172%
# H^2 (total variability / sampling variability):  3.7199
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 10.3951, p-val = 0.9182
# LRT(df = 18) = 35.1275, p-val = 0.0091
#
# Model Results:
#
# estimate      se    zval    pval    ci.lb   ci.ub
#   0.0260  0.0867  0.2999  0.7643  -0.1440  0.1960
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "5 vs 9"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -135.0699    37.6421   278.1399   284.6902   279.3520
#
# tau^2 (estimated amount of total heterogeneity): 0.3947
# tau (square root of estimated tau^2 value):      0.6283
# I^2 (total heterogeneity / total variability):   82.9523%
# H^2 (total variability / sampling variability):  5.8659
#
# sigma^2 (estimated amount of study level variability): 0.0033
# sigma (square root of estimated sigma^2 value):        0.0578
#
# Tests for Heterogeneity:
# Wld(df = 18) =  99.6016, p-val < .0001
# LRT(df = 18) = 121.1953, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -3.5327  0.1596  -22.1324  <.0001  -3.8455  -3.2198  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "6 vs 10"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -127.3714    16.2352   262.7428   269.2931   263.9549
#
# tau^2 (estimated amount of total heterogeneity): 0.0487
# tau (square root of estimated tau^2 value):      0.2206
# I^2 (total heterogeneity / total variability):   54.7997%
# H^2 (total variability / sampling variability):  2.2124
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 23.9316, p-val = 0.1573
# LRT(df = 18) = 23.9855, p-val = 0.1555
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   0.9187  0.0689  13.3259  <.0001  0.7836  1.0539  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "16 vs 17"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -137.5543     3.9906   283.1086   289.6589   284.3207
#
# tau^2 (estimated amount of total heterogeneity): 0.2279
# tau (square root of estimated tau^2 value):      0.4773
# I^2 (total heterogeneity / total variability):   85.3742%
# H^2 (total variability / sampling variability):  6.8372
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 70.4893, p-val < .0001
# LRT(df = 18) = 77.4697, p-val < .0001
#
# Model Results:
#
# estimate      se    zval    pval   ci.lb   ci.ub
#   0.5829  0.1191  4.8946  <.0001  0.3495  0.8162  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "4 vs 11"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -119.4779    19.3918   246.9559   253.5062   248.1680
#
# tau^2 (estimated amount of total heterogeneity): 0
# tau (square root of estimated tau^2 value):      0
# I^2 (total heterogeneity / total variability):   0.0000%
# H^2 (total variability / sampling variability):  1.0000
#
# sigma^2 (estimated amount of study level variability): 0.0010
# sigma (square root of estimated sigma^2 value):        0.0315
#
# Tests for Heterogeneity:
# Wld(df = 18) = 19.3451, p-val = 0.3709
# LRT(df = 18) = 19.3918, p-val = 0.3681
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   1.7037  0.0537  31.7163  <.0001  1.5984  1.8090  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "5 vs 6"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -135.7551    65.5730   279.5102   286.0606   280.7224
#
# tau^2 (estimated amount of total heterogeneity): 0.0529
# tau (square root of estimated tau^2 value):      0.2300
# I^2 (total heterogeneity / total variability):   41.6715%
# H^2 (total variability / sampling variability):  1.7144
#
# sigma^2 (estimated amount of study level variability): 0.0187
# sigma (square root of estimated sigma^2 value):        0.1368
#
# Tests for Heterogeneity:
# Wld(df = 18) = 71.2571, p-val < .0001
# LRT(df = 18) = 69.8576, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -2.7820  0.0824  -33.7791  <.0001  -2.9434  -2.6206  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "9 vs 10"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -132.1912     4.5365   272.3823   278.9327   273.5944
#
# tau^2 (estimated amount of total heterogeneity): 0.1310
# tau (square root of estimated tau^2 value):      0.3620
# I^2 (total heterogeneity / total variability):   72.9881%
# H^2 (total variability / sampling variability):  3.7021
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 15.5557, p-val = 0.6235
# LRT(df = 18) = 35.9668, p-val = 0.0071
#
# Model Results:
#
# estimate      se     zval    pval   ci.lb   ci.ub
#   1.6458  0.0978  16.8219  <.0001  1.4541  1.8376  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "12 vs 13"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -135.9996    21.1233   279.9993   286.5496   281.2114
#
# tau^2 (estimated amount of total heterogeneity): 0.1419
# tau (square root of estimated tau^2 value):      0.3767
# I^2 (total heterogeneity / total variability):   75.7538%
# H^2 (total variability / sampling variability):  4.1244
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 40.1137, p-val = 0.0020
# LRT(df = 18) = 55.6661, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -1.5703  0.1001  -15.6944  <.0001  -1.7664  -1.3742  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# [1] "14 vs 15"
#
# Random-Effects Model (k = 19; tau^2 estimator: ML)
# Model Type: Unconditional Model with Random Study Effects
#
#    logLik   deviance        AIC        BIC       AICc
# -130.3060    37.6583   268.6120   275.1624   269.8242
#
# tau^2 (estimated amount of total heterogeneity): 0.0755
# tau (square root of estimated tau^2 value):      0.2748
# I^2 (total heterogeneity / total variability):   57.8787%
# H^2 (total variability / sampling variability):  2.3741
#
# sigma^2 (estimated amount of study level variability): 0
# sigma (square root of estimated sigma^2 value):        0
#
# Tests for Heterogeneity:
# Wld(df = 18) = 48.4106, p-val = 0.0001
# LRT(df = 18) = 49.5752, p-val < .0001
#
# Model Results:
#
# estimate      se      zval    pval    ci.lb    ci.ub
#  -2.0100  0.0833  -24.1335  <.0001  -2.1733  -1.8468  ***
#
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1

# %% [markdown]
# ### Importing results from heterogeneity analysis to Python

# %%
# %%R
# z_list = as.numeric(unlist(z_list))
# p_list = as.numeric(unlist(p_list))
# I2_list = as.numeric(unlist(I2_list))
# q_list = as.numeric(unlist(q_list))
# qp_list = as.numeric(unlist(qp_list))

# %%
# %R -o z_list
# %R -o p_list
# %R -o I2_list
# %R -o q_list
# %R -o qp_list
z_list = np.array(z_list)
p_list = np.array(p_list)
I2_list = np.array(I2_list)
q_list = np.array(q_list)
qp_list = np.array(qp_list)

# %% [markdown]
# ### Structuring heterogeniety results into dataframe

# %%
het_df = pd.DataFrame([[str(a) + " vs " + str(b) for a, b in zip(PT_contrasts_df2.loc[PT_contrasts_df2["Country"]=="Sweden",
                                                    "Item 1"], PT_contrasts_df2.loc[PT_contrasts_df2["Country"]=="Sweden", "Item 2"])],
                       q_list, qp_list, I2_list, z_list, p_list]).transpose()
het_df.columns = ["Contrasts", "Q (df = 18)", "Q p-value", "I2", "z-statistic", "z p-value"]
het_df["Q (df = 18)"] = het_df["Q (df = 18)"].astype(float).round(2)
#het_df["Q p-value"] = het_df["Q p-value"].round(4)
het_df["I2"] = het_df["I2"].astype(float).round(0).astype(int)
het_df["z-statistic"] = het_df["z-statistic"].astype(float).round(2)
#het_df["z p-value"] = het_df["z p-value"].round(4)
het_df.head()
het_df.to_excel("../output/Meta analysis logodds heterogeneity.xlsx", index=False)
het_df.to_csv("../output/Meta analysis logodds heterogeneity.csv", index=False)

# %%
het_df
# Out:
#    Contrasts  Q (df = 18)    Q p-value  I2  z-statistic     z p-value
# 0     1 vs 2        43.48  0.000684494  50       -22.22  2.30572e-109
# 1     3 vs 4        21.38     0.260489   0       -34.50  7.99424e-261
# 2     7 vs 8         9.86     0.936261   0        26.84  1.05263e-158
# 3     3 vs 7        56.59  7.19013e-06  72       -28.05  3.56816e-173
# 4     4 vs 8        35.13   0.00910908  73         0.30      0.764276
# 5     5 vs 9       121.20  2.49567e-17  83       -22.13  1.54052e-108
# 6    6 vs 10        23.99     0.155504  55        13.33   1.63637e-40
# 7   16 vs 17        77.47  2.36613e-09  85         4.89    9.8492e-07
# 8    4 vs 11        19.39     0.368077   0        31.72  9.24893e-221
# 9     5 vs 6        69.86  4.77705e-08  42       -33.78  4.00268e-250
# 10   9 vs 10        35.97   0.00712547  73        16.82   1.68587e-63
# 11  12 vs 13        55.67  1.00611e-05  76       -15.69   1.65137e-55
# 12  14 vs 15        49.58  8.74899e-05  58       -24.13  1.11172e-128

# %% [markdown]
# ### Importing log-odds results to Python

# %%
# %%R
# lb_list = as.numeric(unlist(lb_list))
# ub_list = as.numeric(unlist(ub_list))
# estimate_list = as.numeric(unlist(estimate_list))
# p_list = as.numeric(unlist(p_list))

# %%
# %R -o lb_list
# %R -o ub_list
# %R -o estimate_list
# %R -o p_list
lb_list = np.array(lb_list)
ub_list = np.array(ub_list)
estimate_list = np.array(estimate_list)
p_list = np.array(p_list)

# %% [markdown]
# ### Structuring results into dataframe

# %%
lodds_df = pd.DataFrame([estimate_list, lb_list, ub_list, p_list]).transpose()
lodds_df.columns = ["lodds", "lb", "ub", "p-value"]
lodds_df.head()
# Out:
#       lodds        lb        ub        p-value
# 0 -1.581017 -1.720487 -1.441547  2.305722e-109
# 1 -1.969901 -2.081812 -1.857990  7.994243e-261
# 2  1.332841  1.235518  1.430164  1.052629e-158
# 3 -3.332428 -3.565245 -3.099612  3.568163e-173
# 4  0.026007 -0.143975  0.195989   7.642756e-01

# %%
lodds_df["Contrasts"] = [str(a) + " vs " + str(b) for a, b in zip(PT_contrasts_df2.loc[PT_contrasts_df2["Country"]=="Sweden",
                                                    "Item 1"], PT_contrasts_df2.loc[PT_contrasts_df2["Country"]=="Sweden", "Item 2"])]

# %%
lodds_df["Succesful Replication"] = "Yes"
lodds_df.loc[lodds_df["p-value"]>.05, "Succesful Replication"] = "No"

# %%
lodds_df
# Out:
#        lodds        lb        ub        p-value Contrasts  \
# 0  -1.581017 -1.720487 -1.441547  2.305722e-109    1 vs 2
# 1  -1.969901 -2.081812 -1.857990  7.994243e-261    3 vs 4
# 2   1.332841  1.235518  1.430164  1.052629e-158    7 vs 8
# 3  -3.332428 -3.565245 -3.099612  3.568163e-173    3 vs 7
# 4   0.026007 -0.143975  0.195989   7.642756e-01    4 vs 8
# 5  -3.532676 -3.845517 -3.219836  1.540525e-108    5 vs 9
# 6   0.918727  0.783602  1.053853   1.636367e-40   6 vs 10
# 7   0.582853  0.349460  0.816246   9.849195e-07  16 vs 17
# 8   1.703716  1.598432  1.809000  9.248932e-221   4 vs 11
# 9  -2.782012 -2.943432 -2.620591  4.002685e-250    5 vs 6
# 10  1.645808  1.454051  1.837565   1.685874e-63   9 vs 10
# 11 -1.570304 -1.766408 -1.374200   1.651368e-55  12 vs 13
# 12 -2.010030 -2.173271 -1.846788  1.111717e-128  14 vs 15
#
#    Succesful Replication
# 0                    Yes
# 1                    Yes
# 2                    Yes
# 3                    Yes
# 4                     No
# 5                    Yes
# 6                    Yes
# 7                    Yes
# 8                    Yes
# 9                    Yes
# 10                   Yes
# 11                   Yes
# 12                   Yes

# %% [markdown]
# # Compute the difference in log-odds between the original results and the meta-analytic results transformed so that larger effects are positive and smaller effects are negative, irrespective of original sign.

# %%
PT_contrasts_original_df = pd.read_excel("../output/original_contrasts.xlsx")

# %%
PT_contrasts_original_df.tail()
# Out:
#                                   Effect  Item 1  Item 2  A1  B1  A2   B2  \
# 8                       Isolation Effect       4      11  62  33  31  110
# 9   Overweighting of small probabilities       5       6   9  57  48   18
# 10  Overweighting of small probabilities       9      10  61   5  20   46
# 11                        Framing Effect      12      13  11  59  47   21
# 12                      Range Adaptation      14      15  12  56  45   19
#
#            OR       p-value        OR2  Significance     LogOR
# 8    6.666667  3.008508e-11   6.666667          True  1.897120
# 9    0.059211  4.830963e-12  16.888889          True -2.826656
# 10  28.060000  6.049779e-14  28.060000          True  3.334345
# 11   0.083303  1.728730e-10  12.004329          True -2.485267
# 12   0.090476  9.017691e-10  11.052632          True -2.402669

# %% [markdown]
# ### Split the contrast column in lor_df to two separate columns (one for each item)

# %%
lodds_df["Item 1"] = lodds_df["Contrasts"].str.split(" vs ", expand=True)[0]
lodds_df["Item 2"] = lodds_df["Contrasts"].str.split(" vs ", expand=True)[1]

# %%
lodds_df["Item 1"] = lodds_df["Item 1"].astype(int)
lodds_df["Item 2"] = lodds_df["Item 2"].astype(int)

# %% [markdown]
# ### Compute the difference in effect size for the central estimates

# %%
lodds_df["LogOR_difference"] = np.nan
for a, b in zip(PT_contrasts_original_df["Item 1"], PT_contrasts_original_df["Item 2"]):
    if np.sign(PT_contrasts_original_df.loc[(PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                         "LogOR"]).values[0] == 1: # If the original log-odds are positive
        lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "LogOR_difference"] = lodds_df.loc[
            (lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "lodds"] - PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "LogOR"].values[0] # Compute the difference between meta analytic effects and original
    else: # If the original log-odds are negative
            lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "LogOR_difference"] =     (lodds_df.loc[
            (lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "lodds"] - PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "LogOR"].values[0]) * -1 # Compute the difference between meta analytic effects and original and multiply by negative 1

# %% [markdown]
# ### Compute the difference in effect size for the upper bounds

# %%
lodds_df["ub_difference"] = np.nan
for a, b in zip(PT_contrasts_original_df["Item 1"], PT_contrasts_original_df["Item 2"]):
    if np.sign(PT_contrasts_original_df.loc[(PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                         "LogOR"]).values[0] == 1: # If the original log-odds are positive
        lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "ub_difference"] =     lodds_df.loc[
            (lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "ub"] - PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "LogOR"].values[0] # Compute the difference between meta analytic effects and original
    else: # If the original log-odds are negative
            lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "ub_difference"] =     (lodds_df.loc[
            (lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "ub"] - PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "LogOR"].values[0]) * -1 # Compute the difference between meta analytic effects and original and multiply by negative 1

# %% [markdown]
# ### Compute the difference in effect size for the lower bounds

# %%
lodds_df["lb_difference"] = np.nan
for a, b in zip(PT_contrasts_original_df["Item 1"], PT_contrasts_original_df["Item 2"]):
    if np.sign(PT_contrasts_original_df.loc[(PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                         "LogOR"]).values[0] == 1: # If the original log-odds are positive
        lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "lb_difference"] =     lodds_df.loc[
            (lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "lb"] - PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "LogOR"].values[0] # Compute the difference between meta analytic effects and original
    else: # If the original log-odds are negative
            lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "lb_difference"] =     (lodds_df.loc[
            (lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "lb"] - PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "LogOR"].values[0]) * -1 # Compute the difference between meta analytic effects and original and multiply by negative 1

# %% [markdown]
# ### Assign effect names to the meta-analytic countrasts

# %%
for a, b in zip(PT_contrasts_original_df["Item 1"], PT_contrasts_original_df["Item 2"]):
    lodds_df.loc[(lodds_df["Item 1"]==a) & (lodds_df["Item 2"]==b),
                             "Effect"] =  PT_contrasts_original_df.loc[
            (PT_contrasts_original_df["Item 1"]==a) & (PT_contrasts_original_df["Item 2"]==b),
                             "Effect"].values[0]

# %%
lodds_df
# Out:
#        lodds        lb        ub        p-value Contrasts  \
# 0  -1.581017 -1.720487 -1.441547  2.305722e-109    1 vs 2
# 1  -1.969901 -2.081812 -1.857990  7.994243e-261    3 vs 4
# 2   1.332841  1.235518  1.430164  1.052629e-158    7 vs 8
# 3  -3.332428 -3.565245 -3.099612  3.568163e-173    3 vs 7
# 4   0.026007 -0.143975  0.195989   7.642756e-01    4 vs 8
# 5  -3.532676 -3.845517 -3.219836  1.540525e-108    5 vs 9
# 6   0.918727  0.783602  1.053853   1.636367e-40   6 vs 10
# 7   0.582853  0.349460  0.816246   9.849195e-07  16 vs 17
# 8   1.703716  1.598432  1.809000  9.248932e-221   4 vs 11
# 9  -2.782012 -2.943432 -2.620591  4.002685e-250    5 vs 6
# 10  1.645808  1.454051  1.837565   1.685874e-63   9 vs 10
# 11 -1.570304 -1.766408 -1.374200   1.651368e-55  12 vs 13
# 12 -2.010030 -2.173271 -1.846788  1.111717e-128  14 vs 15
#
#    Succesful Replication  Item 1  Item 2  LogOR_difference  ub_difference  \
# 0                    Yes       1       2         -1.541009      -1.680479
# 1                    Yes       3       4         -0.047020      -0.158931
# 2                    Yes       7       8         -1.372080      -1.274757
# 3                    Yes       3       7         -0.440333      -0.673149
# 4                     No       4       8         -0.923074      -0.753092
# 5                    Yes       5       9         -0.814586      -1.127427
# 6                    Yes       6      10         -0.895011      -0.759885
# 7                    Yes      16      17         -1.982096      -1.748703
# 8                    Yes       4      11         -0.193404      -0.088120
# 9                    Yes       5       6         -0.044644      -0.206065
# 10                   Yes       9      10         -1.688537      -1.496780
# 11                   Yes      12      13         -0.914963      -1.111067
# 12                   Yes      14      15         -0.392639      -0.555880
#
#     lb_difference                                Effect
# 0       -1.401539                      Certainty Effect
# 1        0.064891                      Certainty Effect
# 2       -1.469403                      Certainty Effect
# 3       -0.207516                     Reflection Effect
# 4       -1.093056                     Reflection Effect
# 5       -0.501746                     Reflection Effect
# 6       -1.030137                     Reflection Effect
# 7       -2.215489                     Reflection Effect
# 8       -0.298688                      Isolation Effect
# 9        0.116777  Overweighting of small probabilities
# 10      -1.880294  Overweighting of small probabilities
# 11      -0.718859                        Framing Effect
# 12      -0.229398                      Range Adaptation

# %%
lodds_df.to_excel("../output/Meta analysis log odds.xlsx", index=False)
lodds_df.to_csv("../output/Meta analysis log odds.csv", index=False)
